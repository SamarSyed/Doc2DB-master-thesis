# %% [markdown]
# This notebook explores examples of the extracted relationships with OpenIE.
#
# The results of this notebook have been stored in csv and pickle files.
# All code cells concerned with the generaiton of those file have been commented out. In case anyone wants to run this file, download the csv files from the google drive link into the folder called "files".

# %% [markdown]
# # Imports

# %%
import _pickle as pickle
import pandas as pd
from tqdm.notebook import tqdm
import os
from collections import defaultdict

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# # Load Triple Dict

# %% [markdown]
# Merged dictionary of all extracted relationship triples from the Harry Potter articles.

# %%
with open(('files\\Harry_Potter_Triple_Labeled'+ '.pickle'), 'rb') as file:
    triple_dicts = pickle.load(file)

# %%
triple_dicts[:20]
# Out:
# [{'subject': ('Nathan Lubbock Smith', 'NO LABEL'),
#   'relation': 'is',
#   'object': ('actor', 'NO LABEL')},
#  {'subject': ('Quidditch Captain', 'PERSON'),
#   'relation': 'is',
#   'object': ('additional position in sport of Quidditch', 'NO LABEL')},
#  {'subject': ('Quidditch Captain', 'PERSON'),
#   'relation': 'is',
#   'object': ('position in sport of Quidditch', 'NO LABEL')},
#  {'subject': ('Captain', 'PRODUCT'),
#   'relation': 'is additional position in',
#   'object': ('sport of Quidditch', 'NO LABEL')},
#  {'subject': ('Quidditch Captain', 'PERSON'),
#   'relation': 'is',
#   'object': ('additional position in wizarding sport of Quidditch',
#    'NO LABEL')},
#  {'subject': ('Captain', 'PRODUCT'),
#   'relation': 'is additional',
#   'object': ('sport', 'NO LABEL')},
#  {'subject': ('Captain', 'PRODUCT'),
#   'relation': 'is additional',
#   'object': ('sport', 'NO LABEL')},
#  {'subject': ('Captain', 'PRODUCT'),
#   'relation': 'is position in',
#   'object': ('sport', 'NO LABEL')},
#  {'subject': ('Captain', 'PRODUCT'),
#   'relation': 'is additional position in',
#   'object': ('wizarding sport of Quidditch', 'NO LABEL')},
#  {'subject': ('Quidditch Captain', 'PERSON'),
#   'relation': 'is',
#   'object': ('position in wizarding sport of Quidditch', 'NO LABEL')},
#  {'subject': ('Quidditch Captain', 'PERSON'),
#   'relation': 'is',
#   'object': ('additional position', 'NO LABEL')},
#  {'subject': ('Quidditch Captain', 'PERSON'),
#   'relation': 'is position in',
#   'object': ('wizarding sport', 'NO LABEL')},
#  {'subject': ('Quidditch Captain', 'PERSON'),
#   'relation': 'is additional position in',
#   'object': ('wizarding sport', 'NO LABEL')},
#  {'subject': ('Quidditch Captain', 'PERSON'),
#   'relation': 'is',
#   'object': ('position', 'NO LABEL')},
#  {'subject': ('Quidditch Captain', 'PERSON'),
#   'relation': 'is additional position in',
#   'object': ('wizarding sport of Quidditch', 'NO LABEL')},
#  {'subject': ('Captain', 'PRODUCT'),
#   'relation': 'is additional position in',
#   'object': ('sport', 'NO LABEL')},
#  {'subject': ('Quidditch Captain', 'PERSON'),
#   'relation': 'is position in',
#   'object': ('wizarding sport of Quidditch', 'NO LABEL')},
#  {'subject': ('Captain', 'PRODUCT'),
#   'relation': 'is additional position in',
#   'object': ('wizarding sport', 'NO LABEL')},
#  {'subject': ('Quidditch Captain', 'PERSON'),
#   'relation': 'is',
#   'object': ('additional position in sport', 'NO LABEL')},
#  {'subject': ('Quidditch Captain', 'PERSON'),
#   'relation': 'is additional position in',
#   'object': ('sport of Quidditch', 'NO LABEL')}]

# %%
with open(('files\\label_pair_count_dict'+ '.pickle'), 'rb') as file:
    label_pair_count_dict = pickle.load(file)

# %%
# label_pair_count_dict

# %%
remove_list = []
for label_pairs in label_pair_count_dict.keys():
    if label_pairs[0] == 'NO LABEL' or label_pairs[1] == 'NO LABEL':
        remove_list.append(label_pairs)
for item in remove_list:
    del label_pair_count_dict[item]

# %% [markdown]
# Most frequent subject - object NER label pairs

# %%
pd.DataFrame({k: v for k, v in sorted(label_pair_count_dict.items(), key=lambda item: item[1], reverse=True)}.items()).head(100)
# Out:
#                              0      1
# 0             (PERSON, PERSON)  29428
# 1                (PERSON, ORG)  21063
# 2                (ORG, PERSON)  14821
# 3               (PERSON, DATE)  13683
# 4                   (ORG, ORG)  13331
# 5                (PERSON, GPE)   6766
# 6                (GPE, PERSON)   5522
# 7                  (ORG, DATE)   5082
# 8                   (GPE, ORG)   3590
# 9                   (ORG, GPE)   2900
# 10           (PERSON, PRODUCT)   2581
# 11                 (GPE, DATE)   2197
# 12             (PERSON, EVENT)   1488
# 13               (LOC, PERSON)   1307
# 14              (ORG, PRODUCT)   1303
# 15                  (LOC, ORG)   1270
# 16                  (GPE, GPE)   1267
# 17               (PERSON, LOC)   1251
# 18              (PRODUCT, ORG)    961
# 19               (PERSON, FAC)    793
# 20                (ORG, EVENT)    743
# 21                  (ORG, LOC)    718
# 22              (PERSON, NORP)    561
# 23       (PERSON, WORK_OF_ART)    540
# 24          (PERSON, CARDINAL)    533
# 25           (PRODUCT, PERSON)    527
# 26                (DATE, DATE)    507
# 27              (PERSON, TIME)    496
# 28                  (ORG, FAC)    429
# 29         (WORK_OF_ART, DATE)    417
# 30              (DATE, PERSON)    411
# 31             (PRODUCT, DATE)    363
# 32          (CARDINAL, PERSON)    360
# 33              (NORP, PERSON)    350
# 34                  (LOC, GPE)    328
# 35          (ORG, WORK_OF_ART)    325
# 36               (FAC, PERSON)    312
# 37                 (ORG, NORP)    287
# 38                 (NORP, ORG)    281
# 39       (WORK_OF_ART, PERSON)    278
# 40              (GPE, PRODUCT)    264
# 41            (PRODUCT, EVENT)    259
# 42                 (LOC, DATE)    251
# 43             (CARDINAL, ORG)    246
# 44                (GPE, EVENT)    216
# 45                  (LOC, FAC)    203
# 46                 (GPE, NORP)    200
# 47             (ORG, CARDINAL)    197
# 48          (GPE, WORK_OF_ART)    197
# 49                 (ORG, TIME)    183
# 50                  (GPE, LOC)    182
# 51              (PRODUCT, GPE)    156
# 52                 (DATE, ORG)    155
# 53          (WORK_OF_ART, ORG)    148
# 54                  (FAC, ORG)    132
# 55                  (FAC, GPE)    124
# 56            (LANGUAGE, DATE)    116
# 57                  (GPE, FAC)    109
# 58              (LOC, PRODUCT)    107
# 59             (ORDINAL, DATE)     93
# 60                 (LOC, TIME)     92
# 61           (PERSON, ORDINAL)     91
# 62            (CARDINAL, DATE)     79
# 63                 (DATE, LOC)     77
# 64  (WORK_OF_ART, WORK_OF_ART)     65
# 65               (EVENT, DATE)     62
# 66              (PRODUCT, FAC)     56
# 67                 (DATE, GPE)     52
# 68          (WORK_OF_ART, GPE)     47
# 69                 (GPE, TIME)     46
# 70                  (LOC, LOC)     45
# 71           (ORDINAL, PERSON)     41
# 72          (PERSON, LANGUAGE)     40
# 73             (GPE, CARDINAL)     39
# 74                 (FAC, DATE)     37
# 75                (EVENT, FAC)     37
# 76             (NORP, ORDINAL)     35
# 77                (EVENT, GPE)     35
# 78            (TIME, CARDINAL)     34
# 79              (ORG, ORDINAL)     31
# 80                 (NORP, GPE)     31
# 81              (GPE, ORDINAL)     29
# 82             (CARDINAL, GPE)     28
# 83             (LOC, CARDINAL)     27
# 84                (DATE, NORP)     26
# 85             (PRODUCT, TIME)     25
# 86             (ORG, QUANTITY)     24
# 87             (CARDINAL, FAC)     21
# 88                 (LOC, NORP)     20
# 89               (NORP, EVENT)     17
# 90             (EVENT, PERSON)     17
# 91             (ORG, LANGUAGE)     14
# 92        (CARDINAL, CARDINAL)     13
# 93             (DATE, PRODUCT)     13
# 94        (WORK_OF_ART, EVENT)     12
# 95                (EVENT, ORG)     12
# 96            (DATE, CARDINAL)     12
# 97              (ORDINAL, ORG)     11
# 98                (NORP, DATE)     11
# 99          (PERSON, QUANTITY)     10

# %% [markdown]
# # Exploring PERSON - PERSON Relationships

# %%
end = len(triple_dicts)
end
# Out:
# 2995084

# %%
PER_PER_relatioships = defaultdict(int)
for i, dct in tqdm(enumerate(triple_dicts), total=end):
    if dct['subject'][1] == 'PERSON' and  dct['object'][1] == 'PERSON':
        PER_PER_relatioships[dct['relation']] += 1
# Out:
#   0%|          | 0/2995084 [00:00<?, ?it/s]

# %% [markdown]
# Most frequent relationship phrases in PERSON - PERSON relationships

# %%
pd.DataFrame({k: v for k, v in sorted(PER_PER_relatioships.items(), key=lambda item: item[1], reverse=True)}.items()).head(100)
# Out:
#                                        0    1
# 0                              fought in  468
# 1                                    met  427
# 2                                     in  409
# 3                                   told  402
# 4                                    was  323
# 5                              's son is  301
# 6                          was killed by  285
# 7                            returned to  279
# 8                                    has  278
# 9                                     at  263
# 10                          's family is  259
# 11                         was struck by  250
# 12                       participated in  213
# 13                             murdering  212
# 14                       biography about  195
# 15         fictionalised biography about  195
# 16  mostly fictionalised biography about  195
# 17                         tortured with  178
# 18                               capture  177
# 19                                seeing  175
# 20                                became  161
# 21                           was branded  156
# 22                                    of  155
# 23                             first met  147
# 24                         was placed by  144
# 25                              disliked  142
# 26                           tortured by  142
# 27                                cursed  127
# 28                               visited  123
# 29                                   had  121
# 30                               went on  120
# 31                              betrayed  119
# 32                                   use  118
# 33                               married  117
# 34                                  asks  115
# 35                                  were  112
# 36                             abandoned  111
# 37                              ' son is  111
# 38                                  save  110
# 39                       was promoted to  109
# 40               were also classmates of  108
# 41                    were classmates of  108
# 42                       travelling with  104
# 43                          protected by  104
# 44                                duress  102
# 45                           Podmore for  101
# 46                                inform  100
# 47                                  take  100
# 48                 later participated in   99
# 49                                   saw   97
# 50                                  kill   96
# 51                        also fought in   96
# 52                             met again   93
# 53                        cleaned out at   93
# 54                                joined   93
# 55                            started at   92
# 56                              murdered   90
# 57                                 asked   90
# 58                              lived at   87
# 59                              attended   87
# 60                                son of   86
# 61                    in Attenborough is   86
# 62                                 plays   85
# 63                       different times   85
# 64                                 times   85
# 65                          's sister is   85
# 66                               is with   83
# 67                                  from   83
# 68                                  used   79
# 69                             fought at   79
# 70                                    to   79
# 71                           reader like   77
# 72                          impersonated   77
# 73                            befriended   72
# 74                                  gave   70
# 75                                killed   70
# 76                               died of   69
# 77                                  left   69
# 78                                  tell   65
# 79                               grew up   64
# 80                                    be   63
# 81                                 visit   63
# 82                              replaced   63
# 83                                  took   62
# 84                             sister of   62
# 85                                taught   61
# 86                          started with   60
# 87                              enemy of   60
# 88                    immediate enemy of   60
# 89                                 is in   60
# 90                              Hermione   59
# 91                             requested   59
# 92                        was visited by   57
# 93                  was later visited by   57
# 94                               conjure   56
# 95                                framed   56
# 96                                  cast   56
# 97                                 train   55
# 98                    being friends with   55
# 99                                skills   55

# %%
PER_PER_names = defaultdict(int)
for i, dct in tqdm(enumerate(triple_dicts), total=end):
    if dct['subject'][1] == 'PERSON' and  dct['object'][1] == 'PERSON':
        PER_PER_names[(dct['subject'][0], dct['object'][0])] += 1
# Out:
#   0%|          | 0/2995084 [00:00<?, ?it/s]

# %% [markdown]
# Most frequent subject - object pairs in PERSON - PERSON relationships

# %%
pd.DataFrame({k: v for k, v in sorted(PER_PER_names.items(), key=lambda item: item[1], reverse=True)}.items()).head(100)
# Out:
#                                             0    1
# 0                            (Godric, Hollow)  750
# 1                               (Rita, Harry)  594
# 2                                (Harry, Ron)  439
# 3                                (Ron, Harry)  432
# 4                          (Pettigrew, Harry)  361
# 5                              (Ginny, Harry)  320
# 6                               (Ron, Battle)  254
# 7                                 (Hog, Head)  248
# 8                              (Dobby, Harry)  240
# 9                     (Minerva, Harry Potter)  222
# 10                            (Rowle, Battle)  198
# 11                                (Ron, Rose)  183
# 12                           (Potters, Harry)  175
# 13               (James Potter, Sirius Black)  171
# 14                           (Chaser, Seeker)  170
# 15               (Peter Pettigrew, Dark Mark)  156
# 16                            (Peter, Sirius)  156
# 17                             (James, Harry)  151
# 18                             (Harry, Harry)  149
# 19                           (Ron, Mundungus)  148
# 20                       (McGonagall, Battle)  148
# 21                     (Amycus, Harry Potter)  142
# 22               (Amycus, Minerva McGonagall)  142
# 97                   (Weasleys, Harry Potter)   67
# 98                          (James, Hogwarts)   66
# 99                              (Percy, Head)   64

# %%
married_df = pd.DataFrame(columns = ['subject', 'married', 'object'])
for i, dct in tqdm(enumerate(triple_dicts), total=end):
    if dct['relation'] == 'married':
        df = {'subject': dct['subject'][0], 'married': dct['relation'], 'object': dct['object'][0]}
        married_df = married_df.append(df, ignore_index = True)
# Out:
#   0%|          | 0/2995084 [00:00<?, ?it/s]

# %%
married_df.head(100)
# Out:
#               subject  married  \
# 0                 Ron  married
# 1                 Ron  married
# 2                 She  married
# 3                  he  married
# 4                  he  married
# 5                Bill  married
# 6                 She  married
# 7                 Ron  married
# 8                 Ron  married
# 9                 Ron  married
# 10                Ron  married
# 11           Narcissa  married
# 12          Bellatrix  married
# 13           Narcissa  married
# 14          Bellatrix  married
# 15          Andromeda  married
# 16          Andromeda  married
# 17          Andromeda  married
# 18                She  married
# 19             notion  married
# 20             notion  married
# 21             notion  married
# 22                Ron  married
# 23                Ron  married
# 24                She  married
# 25                she  married
# 26                she  married
# 27                Cho  married
# 28                Cho  married
# 29                she  married
# 30                 he  married
# 31                Ron  married
# 32                Ron  married
# 33                She  married
# 34         his sister  married
# 35  Monsieur Delacour  married
# 36             George  married
# 37                she  married
# 38         Nymphadora  married
# 39                she  married
# 40                she  married
# 41                she  married
# 42                she  married
# 43                she  married
# 44                she  married
# 45                she  married
# 46                she  married
# 47                she  married
# 48                she  married
# 49                she  married
# 50           Hermione  married
# 51           Hermione  married
# 52                Ted  married
# 53                Ted  married
# 54            his son  married
# 55            his son  married
# 56                 he  married
# 57                 he  married
# 58                 he  married
# 59  Rionach 's sister  married
# 60  Rionach 's sister  married
# 61  Rionach 's sister  married
# 62  Rionach 's sister  married
# 63  Rionach 's sister  married
# 64  Rionach 's sister  married
# 65  Rionach 's sister  married
# 66  Rionach 's sister  married
# 67  Rionach 's sister  married
# 68                she  married
# 69               Rose  married
# 70               Rose  married
# 71               Rose  married
# 72                Ron  married
# 73                Ron  married
# 74                Ron  married
# 75                Ron  married
# 76                Ron  married
# 77                Ron  married
# 78                she  married
# 79  Rionach 's sister  married
# 80  Rionach 's sister  married
# 81  Rionach 's sister  married
# 82  Rionach 's sister  married
# 83  Rionach 's sister  married
# 84  Rionach 's sister  married
# 85  Rionach 's sister  married
# 86  Rionach 's sister  married
# 87  Rionach 's sister  married
# 88                She  married
# 89                 he  married
# 90                 He  married
# 91              Tonks  married
# 92  Rionach 's sister  married
# 93  Rionach 's sister  married
# 94  Rionach 's sister  married
# 95  Rionach 's sister  married
# 96  Rionach 's sister  married
# 97  Rionach 's sister  married
# 98  Rionach 's sister  married
# 99  Rionach 's sister  married
#
#                                                object
# 0                                            Hermione
# 1                                            Hermione
# 2                                        Harry Potter
# 3                                               Ginny
# 4                                               Ginny
# 5                                      Fleur Delacour
# 6                                         Ron Weasley
# 7                                            Hermione
# 8                                            Hermione
